# %%
import pandas as pd
import numpy as np

# %%
commercial = pd.read_excel('Two_wheeler_Raw.xlsx')

# %%
cibil = pd.read_excel('Two_wheeler_Cibil_Score.xlsx')

# %%
commercial.columns
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_DOB', 'cus_MartialTypeId',
#        'cus_Dependants', 'cus_CurrenResTypeId', 'cus_CurrenStyYear',
#        'app_CustBankClosBal', 'app_CustAssetValue', 'app_CustProductCatTypeId',
#        'app_CustBrandTypeId', 'app_CustIndustryTypeId', 'app_CustTenure',
#        'app_CustInstalCount', 'app_CustChasAsset', 'app_CustChasInitial',
#        'app_CustChasFinance', 'app_CustFinanInterest', 'app_CustEMI',
#        'app_CustTotInflow', 'Label'],
#       dtype='object')

# %%
commercial["Score"] = np.nan
commercial["AnotherScore"] = np.nan

# %%
commercial.columns
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_DOB', 'cus_MartialTypeId',
#        'cus_Dependants', 'cus_CurrenResTypeId', 'cus_CurrenStyYear',
#        'app_CustBankClosBal', 'app_CustAssetValue', 'app_CustProductCatTypeId',
#        'app_CustBrandTypeId', 'app_CustIndustryTypeId', 'app_CustTenure',
#        'app_CustInstalCount', 'app_CustChasAsset', 'app_CustChasInitial',
#        'app_CustChasFinance', 'app_CustFinanInterest', 'app_CustEMI',
#        'app_CustTotInflow', 'Label', 'Score', 'AnotherScore'],
#       dtype='object')

# %%
cibil.columns[7:9]
# Out:
# Index(['Score', 'AnotherScore'], dtype='object')

# %%
cnt = 0
for i in range(len(commercial['cus_CustomerCode'])):
    for j in range(len(cibil['CustomerCode'])):
        if commercial['cus_CustomerCode'][i] == cibil['CustomerCode'][j]:
            print('Yes')
            cnt = cnt+1
            print(cnt)
# Out:
# Yes
# 1
# Yes
# 2
# Yes
# 3
# Yes
# 4
# Yes
# 5
# Yes
# 6
# Yes
# 7
# Yes
# 8
# Yes
# 9
# Yes
# 10
# Yes
# 11
# Yes
# 12
# Yes
# 13
# Yes
# 14
# Yes
# 15
# Yes
# 16
# Yes
# 17
# Yes
# 18
# Yes
# 19
# Yes
# 20
# Yes
# 21
# Yes
# 22
# Yes
# 23
# Yes
# 24
# Yes
# 25
# Yes
# 26
# Yes
# 27
# Yes
# 28
# Yes
# 29
# Yes
# 30
# Yes
# 31
# Yes
# 32
# Yes
# 33
# Yes
# 34
# Yes
# 35
# Yes
# 36
# Yes
# 37
# Yes
# 38
# Yes
# 39
# Yes
# 40
# Yes
# 41
# Yes
# 42
# Yes
# 43
# Yes
# 44
# Yes
# 45
# Yes
# 46
# Yes
# 47
# Yes
# 48
# Yes
# 49
# Yes
# 50
# Yes
# 51
# Yes
# 52
# Yes
# 53
# Yes
# 54
# Yes
# 55
# Yes
# 56
# Yes
# 57
# Yes
# 58
# Yes
# 59
# Yes
# 60
# Yes
# 61
# Yes
# 62
# Yes
# 63
# Yes
# 64
# Yes
# 65
# Yes
# 66
# Yes
# 67
# Yes
# 68
# Yes
# 69
            commer = commercial.iloc[i].values.tolist()
            commer[-2:] = cibil.iloc[j].values.tolist()[7:9]
            commercial.iloc[i] = commer

# %%
commercial.shape
# Out:
# (600, 23)

# %%
print(commercial.AnotherScore.isnull().sum())
print(commercial.Score.isnull().sum())
# Out:
# 140
# 140

# %%
null_records = commercial.shape[0] - commercial.AnotherScore.isnull().sum()
print("Their is a {} Records with cibil are found..".format(null_records))
# Out:
# Their is a 460 Records with cibil are found..

# %%
#Pre-processing Cibil Score:
def cibil(x):
    if x == '000-1':
        return 1
    else:
        return x

# %%
commercial.Score = commercial.Score.apply(cibil)

# %%
commercial.Score.value_counts()
# Out:
# 1.0      339
# 2.0        7
# 3.0        6
# 710.0      4
# 706.0      4
#         ...
# 750.0      1
# 740.0      1
# 548.0      1
# 590.0      1
# 721.0      1
# Name: Score, Length: 86, dtype: int64

# %%
for i in commercial.columns:
    print(commercial[i].value_counts())
# Out:
# APTW007146    2
# APTW068546    1
# APTW115169    1
# APTW010991    1
# APTW048325    1
#              ..
# APTW180861    1
# APTW069596    1
# APTW150683    1
# ATTW154548    1
# APTW038227    1
# Name: cus_CustomerCode, Length: 599, dtype: int64
# M    502
# F     98
# Name: cus_Gender, dtype: int64
# 1985-01-01    9
# 1994-01-01    8
# 1991-01-01    7
# 1983-01-01    7
# 1990-01-01    7
#              ..
# 1996-06-08    1
# 1970-08-22    1
# 1992-09-02    1
# 1987-10-07    1
# 1979-04-22    1
# Name: cus_DOB, Length: 498, dtype: int64
# 1900-01-02    447
# 1900-01-01    153
# Name: cus_MartialTypeId, dtype: int64
# 0    411
# 2     70
# 3     41
# 4     40
# 1     27
# 5      8
# 9      1
# 8      1
# 6      1
# Name: cus_Dependants, dtype: int64
# 1    512
# 2     88
# Name: cus_CurrenResTypeId, dtype: int64
# 20    85
# 10    84
# 15    45
# 30    36
# 5     31
# 25    30
# 14    29
# 2     27
# 6     16
# 35    16
# 33    15
# 40    15
# 3     14
# 23    11
# 8     10
# 22    10
# 9      9
# 29     9
# 27     8
# 21     7
# 24     7
# 19     7
# 1      6
# 18     6
# 32     6
# 12     6
# 7      6
# 26     5
# 17     3
# 0      3
# 39     3
# 31     3
# 44     3
# 43     3
# 42     3
# 28     2
# 46     2
# 4      2
# 50     2
# 37     2
# 36     2
# 13     2
# 34     2
# 16     2
# 56     2
# 38     1
# 45     1
# 49     1
# Name: cus_CurrenStyYear, dtype: int64
# 0        376
# 1000      61
# 1500      29
# 5000      22
# 2000      15
# 2500      13
# 6500       9
# 1200       9
# 1100       7
# 10000      7
# 3000       4
# 4500       3
# 500        3
# 6000       3
# 4000       3
# 5500       2
# 15200      2
# 3289       1
# 5349       1
# 12500      1
# 5246       1
# 200        1
# 12458      1
# 5279       1
# 8463       1
# 6249       1
# 100        1
# 5200       1
# 18500      1
# 15400      1
# 8437       1
# 5106       1
# 13625      1
# 4673       1
# 25561      1
# 15222      1
# 8045       1
# 3816       1
# 6819       1
# 7829       1
# 1598       1
# 2400       1
# 63000      1
# 5642       1
# 4592       1
# 4562       1
# 25000      1
# 1400       1
# 3500       1
# Name: app_CustBankClosBal, dtype: int64
# 0          534
# 265000      16
# 250000      11
# 200000      11
# 150000       6
# 245000       5
# 300000       3
# 268000       2
# 285000       2
# 254000       2
# 650000       1
# 1250000      1
# 320000       1
# 215000       1
# 2500000      1
# 154000       1
# 1500000      1
# 1200000      1
# Name: app_CustAssetValue, dtype: int64
# 1541    600
# Name: app_CustProductCatTypeId, dtype: int64
# 1360    231
# 1542    216
# 935      37
# 1544     37
# 816      28
# 1547     20
# 1546     14
# 1647      8
# 1549      6
# 1734      1
# 1545      1
# 1476      1
# Name: app_CustBrandTypeId, dtype: int64
# 1783    281
# 879     140
# 1782     74
# 603      46
# 877      43
# 878       5
# 605       5
# 875       2
# 658       2
# 604       2
# Name: app_CustIndustryTypeId, dtype: int64
# 24    375
# 18    113
# 30     51
# 12     40
# 36     15
# 31      1
# 25      1
# 23      1
# 21      1
# 20      1
# 19      1
# Name: app_CustTenure, dtype: int64
# 24    286
# 18     94
# 23     84
# 30     33
# 12     26
# 17     19
# 29     16
# 11     10
# 36      9
# 22      7
# 35      5
# 10      3
# 28      2
# 21      1
# 20      1
# 27      1
# 16      1
# 34      1
# 9       1
# Name: app_CustInstalCount, dtype: int64
# 56823     9
# 66000     6
# 73500     6
# 62000     6
# 63500     6
#          ..
# 78500     1
# 57000     1
# 75500     1
# 69293     1
# 194560    1
# Name: app_CustChasAsset, Length: 450, dtype: int64
# 13000    8
# 10000    7
# 14000    6
# 11000    6
# 10500    5
#         ..
# 19100    1
# 18452    1
# 12478    1
# 19110    1
# 30200    1
# Name: app_CustChasInitial, Length: 471, dtype: int64
# 45000     20
# 50000     17
# 42000     17
# 40000     17
# 53000     16
#           ..
# 43625      1
# 145000     1
# 38500      1
# 63070      1
# 70600      1
# Name: app_CustChasFinance, Length: 207, dtype: int64
# 13.00    151
# 12.50     69
# 12.00     59
# 13.50     54
# 11.75     45
#         ...
# 12.60      1
# 12.91      1
# 11.34      1
# 11.19      1
# 12.53      1
# Name: app_CustFinanInterest, Length: 64, dtype: int64
# 2835    8
# 2783    7
# 2730    7
# 3413    5
# 2672    5
#        ..
# 2722    1
# 1705    1
# 3531    1
# 1710    1
# 5120    1
# Name: app_CustEMI, Length: 445, dtype: int64
# 2000    110
# 1800    105
# 2300     79
# 1500     64
# 2500     43
# 1300     39
# 1200     30
# 2800     26
# 0        22
# 1000     18
# 500       8
# 1700      8
# 2100      5
# 2700      5
# 3300      4
# 3400      4
# 2200      3
# 3000      3
# 700       2
# 3200      2
# 4300      1
# 2060      1
# 2080      1
# 2600      1
# 2160      1
# 1202      1
# 2240      1
# 200       1
# 3591      1
# 4600      1
# 750       1
# 3335      1
# 3651      1
# 1400      1
# 3450      1
# 5577      1
# 2520      1
# 550       1
# 2580      1
# 3800      1
# Name: app_CustTotInflow, dtype: int64
# Not Pay    400
# Pay        200
# Name: Label, dtype: int64
# 1.0      339
# 2.0        7
# 3.0        6
# 710.0      4
# 706.0      4
#         ...
# 750.0      1
# 740.0      1
# 548.0      1
# 590.0      1
# 721.0      1
# Name: Score, Length: 86, dtype: int64
# 888    117
# 884    115
# 907     38
# 923     35
# 909     15
# 959     13
# 960     11
# 887     10
# 883      9
# 904      8
# 838      5
# 967      5
# 925      5
# 951      5
# 934      4
# 832      4
# 903      4
# 900      4
# 920      3
# 906      3
# 864      3
# 665      2
# 938      2
# 940      2
# 891      2
# 968      2
# 974      2
# 981      2
# 863      2
# 932      2
# 912      1
# 966      1
# 905      1
# 796      1
# 899      1
# 928      1
# 667      1
# 807      1
# 924      1
# 889      1
# 880      1
# 995      1
# 983      1
# 979      1
# 973      1
# 965      1
# 957      1
# 809      1
# 954      1
# 947      1
# 818      1
# 890      1
# 687      1
# 942      1
# 939      1
# 763      1
# Name: AnotherScore, dtype: int64

# %%
#Removing '-' from dataset:
for i in commercial.columns:
    commercial[i][commercial[i] == '-'] = np.nan
# Out:
# C:\Users\ESFITA-USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ESFITA-USER\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
commercial.head()
# Out:
#   cus_CustomerCode cus_Gender    cus_DOB cus_MartialTypeId  cus_Dependants  \
# 0       APTW058710          M 1971-04-09        1900-01-02               0
# 1       APTW058587          M 1994-02-15        1900-01-02               2
# 2       APTW058718          M 1974-09-03        1900-01-02               2
# 3       APTW057714          M 1985-05-07        1900-01-01               4
# 4       APTW060335          M 1970-03-02        1900-01-02               3
#
#    cus_CurrenResTypeId  cus_CurrenStyYear  app_CustBankClosBal  \
# 0                    1                 15                 3289
# 1                    1                 14                 4562
# 2                    1                 16                 5246
# 3                    1                 28                 6249
# 4                    1                 14                 4673
#
#    app_CustAssetValue  app_CustProductCatTypeId  ...  app_CustInstalCount  \
# 0                   0                      1541  ...                   24
# 1                   0                      1541  ...                   18
# 2                   0                      1541  ...                   18
# 3                   0                      1541  ...                   24
# 4                   0                      1541  ...                   24
#
#    app_CustChasAsset  app_CustChasInitial  app_CustChasFinance  \
# 0              63397                21397                42000
# 1              63000                22000                41000
# 2              53747                22747                31000
# 3              61011                19011                42000
# 4              54247                18247                36000
#
#    app_CustFinanInterest  app_CustEMI  app_CustTotInflow  Label  Score  \
# 0                  13.50         2223               1800    Pay    1.0
# 1                  13.00         2722               1800    Pay    1.0
# 2                  10.03         1981               1800    Pay    1.0
# 3                  10.50         2118               1800    Pay    1.0
# 4                  13.50         1905               1800    Pay    1.0
#
#    AnotherScore
# 0           907
# 1           884
# 2           907
# 3           888
# 4           907
#
# [5 rows x 23 columns]

# %%
print(commercial.columns)
print(commercial.isnull().sum())
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_DOB', 'cus_MartialTypeId',
#        'cus_Dependants', 'cus_CurrenResTypeId', 'cus_CurrenStyYear',
#        'app_CustBankClosBal', 'app_CustAssetValue', 'app_CustProductCatTypeId',
#        'app_CustBrandTypeId', 'app_CustIndustryTypeId', 'app_CustTenure',
#        'app_CustInstalCount', 'app_CustChasAsset', 'app_CustChasInitial',
#        'app_CustChasFinance', 'app_CustFinanInterest', 'app_CustEMI',
#        'app_CustTotInflow', 'Label', 'Score', 'AnotherScore'],
#       dtype='object')
# cus_CustomerCode              0
# cus_Gender                    0
# cus_DOB                       0
# cus_MartialTypeId             0
# cus_Dependants                0
# cus_CurrenResTypeId           0
# cus_CurrenStyYear             0
# app_CustBankClosBal           0
# app_CustAssetValue            0
# app_CustProductCatTypeId      0
# app_CustBrandTypeId           0
# app_CustIndustryTypeId        0
# app_CustTenure                0
# app_CustInstalCount           0
# app_CustChasAsset             0
# app_CustChasInitial           0
# app_CustChasFinance           0
# app_CustFinanInterest         0
# app_CustEMI                   0
# app_CustTotInflow             0
# Label                         0
# Score                       140
# AnotherScore                140
# dtype: int64

# %% [markdown]
# ### Feature Handling:

# %%
commercial.cus_MartialTypeId.value_counts()
# Out:
# 1900-01-02    447
# 1900-01-01    153
# Name: cus_MartialTypeId, dtype: int64

# %%
def mar(x):
    """
    Method to handle MarialTypeId Feature.
    """
    if x == 2:
        return 2751
    else:
        return 2750

# %%
commercial.cus_MartialTypeId = commercial.cus_MartialTypeId.apply(mar)

# %%
commercial.cus_MartialTypeId.value_counts()
# Out:
# 2750    600
# Name: cus_MartialTypeId, dtype: int64

# %%
commercial.shape
# Out:
# (600, 23)

# %%
commercial.cus_MartialTypeId.fillna(commercial.cus_MartialTypeId.value_counts().index[0],inplace=True)

# %%
commercial.cus_MartialTypeId.value_counts()
# Out:
# 2750    600
# Name: cus_MartialTypeId, dtype: int64

# %%
commercial.cus_Gender.value_counts()
# Out:
# M    502
# F     98
# Name: cus_Gender, dtype: int64

# %%
def gen(x):
    """
    Method to handle MarialTypeId Feature.
    """
    if x == " ":
        return np.nan
    if x == 1:
        return "M"
    else:
        return x

# %%
commercial.cus_Gender = commercial.cus_Gender.apply(gen)

# %%
commercial.cus_Gender.fillna(commercial.cus_Gender.value_counts().index[0],inplace=True)

# %%
commercial.cus_Gender.value_counts()
# Out:
# M    502
# F     98
# Name: cus_Gender, dtype: int64

# %%
commercial.cus_CurrenResTypeId.value_counts()
# Out:
# 1    512
# 2     88
# Name: cus_CurrenResTypeId, dtype: int64

# %%
def res_type(x):
    """
    Method to handle ResiTypeId Feature.
    """
    if x == 1:
        return 2755
    if x == 2:
        return 2756
    else:
        return x

# %%
commercial.cus_CurrenResTypeId = commercial.cus_CurrenResTypeId.apply(res_type)

# %%
commercial.cus_CurrenResTypeId.fillna(commercial.cus_CurrenResTypeId.value_counts().index[0],inplace=True)

# %%
commercial.cus_CurrenResTypeId.value_counts()
# Out:
# 2755    512
# 2756     88
# Name: cus_CurrenResTypeId, dtype: int64

# %%
commercial.app_CustIndustryTypeId.value_counts()
# Out:
# 1783    281
# 879     140
# 1782     74
# 603      46
# 877      43
# 878       5
# 605       5
# 875       2
# 658       2
# 604       2
# Name: app_CustIndustryTypeId, dtype: int64

# %%
commercial.app_CustIndustryTypeId.fillna(commercial.app_CustIndustryTypeId.value_counts().index[0],inplace=True)

# %%
commercial.app_CustIndustryTypeId.value_counts()
# Out:
# 1783    281
# 879     140
# 1782     74
# 603      46
# 877      43
# 878       5
# 605       5
# 875       2
# 658       2
# 604       2
# Name: app_CustIndustryTypeId, dtype: int64

# %%
commercial.app_CustProductCatTypeId.value_counts()
# Out:
# 1541    600
# Name: app_CustProductCatTypeId, dtype: int64

# %%
commercial.app_CustProductCatTypeId.fillna(commercial.app_CustProductCatTypeId.value_counts().index[0],inplace=True)

# %%
commercial.app_CustProductCatTypeId.value_counts()
# Out:
# 1541    600
# Name: app_CustProductCatTypeId, dtype: int64

# %%
commercial.app_CustBrandTypeId.value_counts()
# Out:
# 1360    231
# 1542    216
# 935      37
# 1544     37
# 816      28
# 1547     20
# 1546     14
# 1647      8
# 1549      6
# 1734      1
# 1545      1
# 1476      1
# Name: app_CustBrandTypeId, dtype: int64

# %%
commercial.app_CustBrandTypeId.fillna(commercial.app_CustBrandTypeId.value_counts().index[0],inplace=True)

# %%
commercial.isnull().sum()
# Out:
# cus_CustomerCode              0
# cus_Gender                    0
# cus_DOB                       0
# cus_MartialTypeId             0
# cus_Dependants                0
# cus_CurrenResTypeId           0
# cus_CurrenStyYear             0
# app_CustBankClosBal           0
# app_CustAssetValue            0
# app_CustProductCatTypeId      0
# app_CustBrandTypeId           0
# app_CustIndustryTypeId        0
# app_CustTenure                0
# app_CustInstalCount           0
# app_CustChasAsset             0
# app_CustChasInitial           0
# app_CustChasFinance           0
# app_CustFinanInterest         0
# app_CustEMI                   0
# app_CustTotInflow             0
# Label                         0
# Score                       140
# AnotherScore                140
# dtype: int64

# %%
commercial.columns
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_DOB', 'cus_MartialTypeId',
#        'cus_Dependants', 'cus_CurrenResTypeId', 'cus_CurrenStyYear',
#        'app_CustBankClosBal', 'app_CustAssetValue', 'app_CustProductCatTypeId',
#        'app_CustBrandTypeId', 'app_CustIndustryTypeId', 'app_CustTenure',
#        'app_CustInstalCount', 'app_CustChasAsset', 'app_CustChasInitial',
#        'app_CustChasFinance', 'app_CustFinanInterest', 'app_CustEMI',
#        'app_CustTotInflow', 'Label', 'Score', 'AnotherScore'],
#       dtype='object')

# %%
def dob(x):
    year = str(x).split('-')[0]
    curr_year = 2020
    return (curr_year-int(year))

# %%
commercial['cus_Age'] = commercial.cus_DOB.apply(dob)

# %%
commercial.drop('cus_DOB',axis=1,inplace=True)

# %%
commercial.columns
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_MartialTypeId', 'cus_Dependants',
#        'cus_CurrenResTypeId', 'cus_CurrenStyYear', 'app_CustBankClosBal',
#        'app_CustAssetValue', 'app_CustProductCatTypeId', 'app_CustBrandTypeId',
#        'app_CustIndustryTypeId', 'app_CustTenure', 'app_CustInstalCount',
#        'app_CustChasAsset', 'app_CustChasInitial', 'app_CustChasFinance',
#        'app_CustFinanInterest', 'app_CustEMI', 'app_CustTotInflow', 'Label',
#        'Score', 'AnotherScore', 'cus_Age'],
#       dtype='object')

# %%
loan_to_value = []
frame = commercial[['app_CustChasAsset','app_CustChasFinance']]
loan = (frame.app_CustChasFinance*100/frame.app_CustChasAsset)

# %%
for i in loan:
    if (i<85):
        loan_to_value.append(120)
    elif ((i>=85) and (i <=90)):
        loan_to_value.append(100)
    elif (i>90):
        loan_to_value.append(50)

# %%
commercial["Loan_to_Value"] = loan_to_value

# %%
asset_finance = []
frame = commercial.app_CustBrandTypeId

# %%
for i in frame:
    # Approved Models (Hero /Honda/Suzuki  - All Products)
    if ((i == 1360) | (i == 1542) | (i == 1544) | (i == 1546)):
        asset_finance.append(100)
    
    # Unapproved Models (Only Yahama, TVS and Royal Enfield Bike Variants) with PM Approval:
    elif ((i == 1547) | (i == 1647) | (i == 935) | (i == 1549)):  
        asset_finance.append(50)
    
    else:
        asset_finance.append(-100)

# %%
commercial["Asset_Financed"] = asset_finance

# %%
gi = []
frame = commercial.app_CustTotInflow*12

# %%
for i in frame:
    if i > 12000:
        gi.append(100)
    elif i>8000 and i<=12000:
        gi.append(70)
    elif i >= 5000 and i<=8000:
        gi.append(50)
    elif i < 5000:
        gi.append(-50)

# %%
commercial["Gross Income"] = gi

# %%
commercial.columns
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_MartialTypeId', 'cus_Dependants',
#        'cus_CurrenResTypeId', 'cus_CurrenStyYear', 'app_CustBankClosBal',
#        'app_CustAssetValue', 'app_CustProductCatTypeId', 'app_CustBrandTypeId',
#        'app_CustIndustryTypeId', 'app_CustTenure', 'app_CustInstalCount',
#        'app_CustChasAsset', 'app_CustChasInitial', 'app_CustChasFinance',
#        'app_CustFinanInterest', 'app_CustEMI', 'app_CustTotInflow', 'Label',
#        'Score', 'AnotherScore', 'cus_Age', 'Loan_to_Value', 'Asset_Financed',
#        'Gross Income'],
#       dtype='object')

# %%
frame = commercial[['app_CustEMI','app_CustBankClosBal','cus_CurrenResTypeId', 'cus_CurrenStyYear','AnotherScore']]
list1 = frame.values.tolist()

# %%
banking = []
for i in list1:
    if ((i[0]>i[1]) and (i[2] == 2756 and i[3]>3)):
        banking.append(100)
    elif ((i[0]>i[1]) and (i[2] == 2755)):
        banking.append(100)
    elif ((i[0]>i[1]) and (i[2] == 2756 and i[3]>2)):
        banking.append(80)
    elif ((i[0]<i[1]) or (i[2] == 2756 and i[3]<2)):
        banking.append(-100)
    elif i[4]>600:
        banking.append(100)

# %%
len(banking)
# Out:
# 600

# %%
commercial["Banking"] = banking

# %%
stabiltiy = []
for i in range(commercial.shape[0]):
        stabiltiy.append(int(np.random.choice([100,80,-80],1)))

# %%
len(stabiltiy)
# Out:
# 600

# %%
commercial["Employment_Stabilty"] = stabiltiy

# %%
frame = commercial[['cus_Age','cus_MartialTypeId', 'cus_Dependants']]
list1 = frame.values.tolist()

# %%
age = []
for i in list1:
    #Age between 21 and 50 years, Married with No Dependents
    if ((i[0]>=21 and i[0]<=50) and (i[1]==2750 and i[2] == 0)):
        age.append(120)
        
    #Age between 21 and 50 years, Married with Dependents
    elif ((i[0]>=21 and i[0]<=50) and (i[1]==2750 and i[2] != 0)):
        age.append(100)
        
    #Age between 51 and 62 years, Married with Dependents
    elif ((i[0]>=51 and i[0]<=62) and (i[1]==2750 and i[2] == 0)):
        age.append(80)
        
    #Age between 51 and 62 years, Married with Dependents
    elif ((i[0]>=51 and i[0]<=62) and (i[1]==2750 and i[2] != 0)):
        age.append(60)
        
    #Age between 21 and 40 years, Married with Dependents
    elif ((i[0]>=21 and i[0]<=40) and (i[1]==2751)):
        age.append(100)
        
    else:
        age.append(0)

# %%
len(age)
# Out:
# 600

# %%
commercial["Age_Martial"] = age

# %%
commercial = commercial[['cus_CustomerCode', 'cus_Gender', 'cus_MartialTypeId', 'cus_Dependants',
       'cus_CurrenResTypeId', 'cus_CurrenStyYear', 'app_CustBankClosBal',
       'app_CustAssetValue', 'app_CustProductCatTypeId', 'app_CustBrandTypeId',
       'app_CustIndustryTypeId', 'app_CustTenure', 'app_CustInstalCount',
       'app_CustChasAsset', 'app_CustChasInitial', 'app_CustChasFinance',
       'app_CustFinanInterest', 'app_CustEMI', 'app_CustTotInflow',
       'Score', 'AnotherScore', 'cus_Age', 'Loan_to_Value', 'Asset_Financed',
       'Gross Income', 'Banking', 'Employment_Stabilty', 'Age_Martial', 'Label']]

# %%
commercial.columns
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_MartialTypeId', 'cus_Dependants',
#        'cus_CurrenResTypeId', 'cus_CurrenStyYear', 'app_CustBankClosBal',
#        'app_CustAssetValue', 'app_CustProductCatTypeId', 'app_CustBrandTypeId',
#        'app_CustIndustryTypeId', 'app_CustTenure', 'app_CustInstalCount',
#        'app_CustChasAsset', 'app_CustChasInitial', 'app_CustChasFinance',
#        'app_CustFinanInterest', 'app_CustEMI', 'app_CustTotInflow', 'Score',
#        'AnotherScore', 'cus_Age', 'Loan_to_Value', 'Asset_Financed',
#        'Gross Income', 'Banking', 'Employment_Stabilty', 'Age_Martial',
#        'Label'],
#       dtype='object')

# %%
commercial['Geo_Limit'] = [int(np.random.choice([0,1],1)) for i in range(commercial.shape[0])]
# Out:
# C:\Users\ESFITA-USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
commercial
# Out:
#     cus_CustomerCode cus_Gender  cus_MartialTypeId  cus_Dependants  \
# 0         APTW058710          M               2750               0
# 1         APTW058587          M               2750               2
# 2         APTW058718          M               2750               2
# 3         APTW057714          M               2750               4
# 4         APTW060335          M               2750               3
# ..               ...        ...                ...             ...
# 595       APTW049489          M               2750               2
# 596       APTW022896          M               2750               0
# 597       APTW048649          M               2750               0
# 598       APTW048908          M               2750               0
# 599       APTW014729          M               2750               1
#
#      cus_CurrenResTypeId  cus_CurrenStyYear  app_CustBankClosBal  \
# 0                   2755                 15                 3289
# 1                   2755                 14                 4562
# 2                   2755                 16                 5246
# 3                   2755                 28                 6249
# 4                   2755                 14                 4673
# ..                   ...                ...                  ...
# 595                 2755                 20                    0
# 596                 2755                 22                    0
# 597                 2755                 10                    0
# 598                 2755                  2                 2000
# 599                 2755                 30                    0
#
#      app_CustAssetValue  app_CustProductCatTypeId  app_CustBrandTypeId  ...  \
# 0                     0                      1541                 1360  ...
# 1                     0                      1541                 1542  ...
# 2                     0                      1541                 1542  ...
# 3                     0                      1541                 1360  ...
# 4                     0                      1541                 1542  ...
# ..                  ...                       ...                  ...  ...
# 595                   0                      1541                 1546  ...
# 596                   0                      1541                 1544  ...
# 597                   0                      1541                 1542  ...
# 598                   0                      1541                  816  ...
# 599                   0                      1541                  935  ...
#
#      AnotherScore  cus_Age  Loan_to_Value  Asset_Financed  Gross Income  \
# 0             907       49            120             100           100
# 1             884       26            120             100           100
# 2             907       46            120             100           100
# 3             888       35            120             100           100
# 4             907       50            120             100           100
# ..            ...      ...            ...             ...           ...
# 595           NaN       41            120             100           100
# 596           NaN       29            120             100           100
# 597           NaN       44            120             100           100
# 598           NaN       45            120            -100           100
# 599           NaN       56            120              50           100
#
#      Banking  Employment_Stabilty  Age_Martial    Label  Geo_Limit
# 0       -100                   80          120      Pay          0
# 1       -100                  100          100      Pay          0
# 2       -100                   80          100      Pay          0
# 3       -100                  100          100      Pay          0
# 4       -100                  -80          100      Pay          0
# ..       ...                  ...          ...      ...        ...
# 595      100                   80          100  Not Pay          1
# 596      100                   80          120  Not Pay          0
# 597      100                   80          120  Not Pay          1
# 598      100                   80          120  Not Pay          1
# 599      100                  -80           60  Not Pay          0
#
# [600 rows x 30 columns]

# %%
commercial = commercial[['cus_CustomerCode', 'cus_Gender', 'cus_MartialTypeId', 'cus_Dependants',
       'cus_CurrenResTypeId', 'cus_CurrenStyYear', 'app_CustBankClosBal',
       'app_CustAssetValue', 'app_CustProductCatTypeId', 'app_CustBrandTypeId',
       'app_CustIndustryTypeId', 'app_CustTenure', 'app_CustInstalCount',
       'app_CustChasAsset', 'app_CustChasInitial', 'app_CustChasFinance',
       'app_CustFinanInterest', 'app_CustEMI', 'app_CustTotInflow', 'Score',
       'AnotherScore', 'cus_Age', 'Loan_to_Value', 'Asset_Financed',
       'Gross Income', 'Banking', 'Employment_Stabilty', 'Age_Martial',
       'Geo_Limit','Label']]

# %%
commercial.columns
# Out:
# Index(['cus_CustomerCode', 'cus_Gender', 'cus_MartialTypeId', 'cus_Dependants',
#        'cus_CurrenResTypeId', 'cus_CurrenStyYear', 'app_CustBankClosBal',
#        'app_CustAssetValue', 'app_CustProductCatTypeId', 'app_CustBrandTypeId',
#        'app_CustIndustryTypeId', 'app_CustTenure', 'app_CustInstalCount',
#        'app_CustChasAsset', 'app_CustChasInitial', 'app_CustChasFinance',
#        'app_CustFinanInterest', 'app_CustEMI', 'app_CustTotInflow', 'Score',
#        'AnotherScore', 'cus_Age', 'Loan_to_Value', 'Asset_Financed',
#        'Gross Income', 'Banking', 'Employment_Stabilty', 'Age_Martial',
#        'Geo_Limit', 'Label'],
#       dtype='object')

# %%
commercial.to_csv('Train_Data_TW.csv',index=False)
